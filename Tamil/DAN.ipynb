# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# Load datasets from Google Drive
train_data_path = '/content/drive/MyDrive/Saracastic/sarcasm_tam_train.csv'
test_data_path = '/content/drive/MyDrive/Saracastic/sarcasm_tam_test_without_labels.csv'

train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)

# %%
# Display the first few rows of the datasets
print(train_data.head())
print(test_data.head())
# Out:
#                                                 Text         labels
# 0  அர்யவுக்கு  ஒரு நல்ல வாய்ப்பு சிங்கம் சூரியா அ...  Non-sarcastic
# 1  பள்ளியோ கல்லூரியோ படித்துக்கொண்டிருக்கும்போது ...  Non-sarcastic
# 2  தல தல தல தல தல தல தல தல தல தல தல தல தல தல தல த...  Non-sarcastic
# 3  All the best to the team....super ah na Oru ka...  Non-sarcastic
# 4  Bahut over mack up kiya hua hai, it is look li...  Non-sarcastic
#       ID                                               Text
# 0  Id_01      Kangana wow  awesome yr ye lakdi sbae alh hai
# 1  Id_02  விழுப்புரம்  வன்னிய கவுண்டர் சார்பாக வாழ்த்துக...
# 2  Id_03  திரௌபதி திரைப்படம் வெற்றி பெற வாணியர் சமுதாயம்...
# 3  Id_04  இந்த திரைப்படம் வெற்றிபெற, ஆதி தமிழன் அதாவது இ...
# 4  Id_05  dai thala pera sonnalay summa tamil naday athi...

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding, GlobalAveragePooling1D, Dense
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

# %%
# Extract features and labels
texts = train_data['Text'].astype(str).values
labels = train_data['labels'].astype(str).values

# %%
# Encode labels (sarcastic/non-sarcastic)
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

# %%
# Tokenize and pad the sequences
vocab_size = 10000
embedding_dim = 100
max_length = 100
oov_tok = "<OOV>"

# %%
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post', truncating='post')

# %%
# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(padded_sequences, labels_encoded, test_size=0.2, random_state=42)

# %%
# DAN Model
model = Sequential([
    Embedding(vocab_size, embedding_dim, input_length=max_length),
    GlobalAveragePooling1D(),
    Dense(24, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Training
model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val), verbose=2)
# Out:
# Epoch 1/10
# 740/740 - 23s - loss: 0.5470 - accuracy: 0.7365 - val_loss: 0.4967 - val_accuracy: 0.7301 - 23s/epoch - 31ms/step
# Epoch 2/10
# 740/740 - 13s - loss: 0.4419 - accuracy: 0.7786 - val_loss: 0.4480 - val_accuracy: 0.7883 - 13s/epoch - 17ms/step
# Epoch 3/10
# 740/740 - 14s - loss: 0.3824 - accuracy: 0.8251 - val_loss: 0.4557 - val_accuracy: 0.7886 - 14s/epoch - 19ms/step
# Epoch 4/10
# 740/740 - 17s - loss: 0.3452 - accuracy: 0.8478 - val_loss: 0.4535 - val_accuracy: 0.7912 - 17s/epoch - 23ms/step
# Epoch 5/10
# 740/740 - 20s - loss: 0.3192 - accuracy: 0.8617 - val_loss: 0.4692 - val_accuracy: 0.7902 - 20s/epoch - 27ms/step
# Epoch 6/10
# 740/740 - 12s - loss: 0.2983 - accuracy: 0.8712 - val_loss: 0.4934 - val_accuracy: 0.7940 - 12s/epoch - 17ms/step
# Epoch 7/10
# 740/740 - 13s - loss: 0.2818 - accuracy: 0.8789 - val_loss: 0.5141 - val_accuracy: 0.7873 - 13s/epoch - 17ms/step
# Epoch 8/10
# 740/740 - 12s - loss: 0.2672 - accuracy: 0.8868 - val_loss: 0.5540 - val_accuracy: 0.7918 - 12s/epoch - 16ms/step
# Epoch 9/10
# 740/740 - 13s - loss: 0.2583 - accuracy: 0.8901 - val_loss: 0.5618 - val_accuracy: 0.7721 - 13s/epoch - 18ms/step
# Epoch 10/10
# 740/740 - 12s - loss: 0.2487 - accuracy: 0.8944 - val_loss: 0.5954 - val_accuracy: 0.7839 - 12s/epoch - 16ms/step

# %%
# Preprocess the test data
test_texts = test_data['Text'].astype(str).values
test_sequences = tokenizer.texts_to_sequences(test_texts)
test_padded = pad_sequences(test_sequences, maxlen=max_length, padding='post', truncating='post')

# %%
# Prediction and Evaluation
val_pred = model.predict(X_val)
val_pred = (val_pred > 0.5).astype(int)
# Out:
# 185/185 [==============================] - 1s 4ms/step

# %%
accuracy = accuracy_score(y_val, val_pred)
precision = precision_score(y_val, val_pred)
recall = recall_score(y_val, val_pred)
f1 = f1_score(y_val, val_pred)
classification_rep = classification_report(y_val, val_pred, target_names=label_encoder.classes_)

# %%
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(classification_rep)
# Out:
# Accuracy: 0.7839026039905309
# Precision: 0.6193693693693694
# Recall: 0.5169172932330827
# F1 Score: 0.5635245901639343
#                precision    recall  f1-score   support
#
# Non-sarcastic       0.83      0.88      0.86      4318
#     Sarcastic       0.62      0.52      0.56      1596
#
#      accuracy                           0.78      5914
#     macro avg       0.73      0.70      0.71      5914
#  weighted avg       0.77      0.78      0.78      5914

# %%
# Decode the predicted labels
predicted_labels = label_encoder.inverse_transform(val_pred.flatten())

# %%
# Print the predictions
for i, text in enumerate(test_texts):
    print(f"Text: {text}\nPredicted Label: {predicted_labels[i]}\n")
# Out:
# Text: Kangana wow  awesome yr ye lakdi sbae alh hai
# Predicted Label: Sarcastic
#
# Text: விழுப்புரம்  வன்னிய கவுண்டர் சார்பாக வாழ்த்துக்கள்
# Predicted Label: Non-sarcastic
#
# Text: திரௌபதி திரைப்படம் வெற்றி பெற வாணியர் சமுதாயம் சார்பாக வாழ்த்துக்கள்
# Predicted Label: Non-sarcastic
#
# Text: இந்த திரைப்படம் வெற்றிபெற, ஆதி தமிழன் அதாவது இந்த சமுதாயம் பிரித்து வைத்த முறைபடி ராகுல் புல்லார் பறையரின் மனமார்ந்த வாழ்த்துக்கள்..
# Predicted Label: Non-sarcastic
#
# Text: dai thala pera sonnalay summa tamil naday athirum daa
# Predicted Label: Non-sarcastic
#
# Text: enakku koncham payama irukku sankar thalavar ah vachi cartoon padam ethum kattirakoodathu :(
# Predicted Label: Sarcastic
#
# Text: Thalaivaa vaa vaa .....Thaa evanum kitta vara kudadhu
# Predicted Label: Non-sarcastic
#
# Text: Haha Sema documentary thetre ku varudhu polayae
# Predicted Label: Non-sarcastic
#
# Text: Surya Ku pair illa ya ?
# Predicted Label: Non-sarcastic
#
# Text: Kaithi trailer yen trending la varala
# Predicted Label: Non-sarcastic
#
# Text: Neenga ept padam edukka edukka than neenga solra kathal athikam aga poguthu da
# Predicted Label: Non-sarcastic
#
# Text: Let’s make it 30M , kabali, Kaala and now Petta
# Predicted Label: Sarcastic
#
# Text: புது முயற்சி மாபெரும் புரட்சி வெற்றி பெற வாழ்த்துக்கள் இல்ல வெற்றி படத்தை தந்தத்துக்கு   வாழ்த்துக்கள் படகுழுவிற்கு கோடி நன்றி
# Predicted Label: Non-sarcastic
#
# Text: Zee tamil la intha movie pakkura ipo
# Predicted Label: Sarcastic
#
# Text: இந்த டிரைலை ஒரு தடவைக்கு  மேல பார்த்தவங்க லைக் போடுங்க
# Predicted Label: Sarcastic
#
# Text: Thala eppavome gethuuuuu thanks thala ilu
# Predicted Label: Non-sarcastic
#
# Text: sbuvum neeyum onnu..rendu peru padamum ithuku mela varathu .rendum therma irunthum keduthukichi
# Predicted Label: Sarcastic
#
# Text: Gotha like kuda vanga mudiyala neeyalam enga annan thalapathy compateator poda aamai kunjugala poi   savunga da
# Predicted Label: Non-sarcastic
#
# Text: பஞ்சமி நிலம் என்பது உண்மை யடி பாப்பா.....  அதை திருடர் மு க கொள்ளை அடித்ததடி பாப்பா....
# Predicted Label: Non-sarcastic
#
# Text: Adhu epdi pa views 44k like matum 55k .Epdi possible
# Predicted Label: Non-sarcastic
#
# Text: except last scene its a crap
# Predicted Label: Sarcastic
#
# Text: Nenga padam eduthu sammbathepika nanga paakanuma
# Predicted Label: Non-sarcastic
#
# Text: Yetho inimeyavathu nalla stories a choose panna sari
# Predicted Label: Non-sarcastic
#
# Text: Vera level   love u chiyaan Anna
# Predicted Label: Non-sarcastic
#
# Text: Jayam Ravi fans like podunga
# Predicted Label: Sarcastic
#
# Text: Oruthar mela neenga viswasam kaatrathukkaga innoruthara en asingapaduthringa to Vijay fans and Ajith fans
# Predicted Label: Non-sarcastic
#
# Text: Mass thalaivar and karthik subaraj Vera level movie sure
# Predicted Label: Non-sarcastic
#
# Text: surya sir flim teaser vera level tq kv.annand sir
# Predicted Label: Non-sarcastic
#
# Text: Yenga anna yeppov super hero dhan
# Predicted Label: Non-sarcastic
#
# Text: Dhanush anna die hard fans like here
# Predicted Label: Non-sarcastic
#
# Text: iam thalapathi fan but 2years hardworking ku nala movie ya irukum nu naa ninaikuran siva sir nice then thala rocking
# Predicted Label: Non-sarcastic
#
# Text: மேலும் இது போன்ற பல திரைபடங்கள் எதிர்காலத்தில் வரவேண்டும். சங்கே முழங்கு சாதிகள் உள்ளது என... தீரன் அண்ணன்மார் ரத்தம் தீராத யுத்தம்......
# Predicted Label: Non-sarcastic
#
# Text: இந்த  படத்துக்கு  எவ்வளவு  ஆதரவுனு  இங்க  கமெண்ட்ட  படிக்கும்போதே  புள்ளரிக்குது.  படக்குழுவினருக்கு  படம்  மிகப்பெரிய  வெற்றியடைய  வாழ்த்துக்கள்.
# Predicted Label: Non-sarcastic
#
# Text: #Vijay jii Inga ennah pandringa ingaium ungaal kootitu vantangla.....
# Predicted Label: Sarcastic
#
# Text: பட்டியலின மக்களை வைத்து அரசியல் செய்யும் அரசியல் சாக்கடை புழுக்களின் தோலுரிக்க வருகிறாள் இந்த திரௌபதி.  அனைவரும் திரையரங்கிற்கு சென்று பார்த்து இப்படத்தை மாபெரும் வெற்றியடையச்செய்வோம்.
# Predicted Label: Non-sarcastic
#
# Text: 1st day la 3 shows kku ticket eduthuttu padam release aagaama kola gaandla irukkaen..  ..
# Predicted Label: Sarcastic
#
# Text: Asusual vijay from sura madurey and vettaikaran
# Predicted Label: Non-sarcastic
#
# Text: Kula thozhil thiruttu pappa aana aanda parambaranu peethipom pappa... Kaata emathi vanguvom pappa apram kaata vithe kudipom pappa... Jaathi peruma pesittu suthuvom pappa oora vittu veliya pona otha vangittu varuvom pappa... Aanda jathi nu sollipom pappa ana enga v2 pengalaye adimaya vachipom pappa.... Veeratha pathi pesuvom pappa ana pappankitta mattum kumututtu poiduvom pappa... Udamba nalla valappom pappa ana ariva valakkama tik tok la jathi video poduvom pappa.... Dai sollanumna yar venalum sollalam... Ella samuthayathulayum nallavanum irukkan kevalamanavanum irukkan...,🤐🤫
# Predicted Label: Sarcastic
#
# Text: South India SUPER STAR VIYAY Anna varlam va varlam va seekiram.
# Predicted Label: Non-sarcastic
#
# Text: அதான் ஒரு படம் கூட நல்ல படம் வந்துடக் கூடாது இதே வேலைய தருவீங்களா
# Predicted Label: Non-sarcastic
#
# Text: Any idea about 8.8k dislikers? 🤔🤔
# Predicted Label: Non-sarcastic
#
# Text: Petta block boster movie in telugu Telugu fans like
# Predicted Label: Non-sarcastic
#
# Text: 2 kids pathieathinga yena ungalku pueiyadh
# Predicted Label: Sarcastic
#
# Text: yanga thalapathi tha da vasul manan.....#manda
# Predicted Label: Non-sarcastic
#
# Text: Antha last la vara blue stata antha kandi pota oru tha** yara mari erukunu yosichu parung
# Predicted Label: Non-sarcastic
#
# Text: Thalapathy vijay saarbaga padam vetri pera vaazhthukal....
# Predicted Label: Non-sarcastic
#
# Text: HERO மூஞ்சி ய பார்த்தா தான் சிரிப்பா வருது...
# Predicted Label: Non-sarcastic
#
# Text: மாபெரும் வெற்றிக்கு தல ரசிகர்கள் சார்பில் வாழ்த்துக்கள்
# Predicted Label: Non-sarcastic
#
# Text: I enjoy it konkana rauth fans  hit like
# Predicted Label: Non-sarcastic
#
# Text: Ama athu enna last la loose motion pora Maari nadanthu varathu..,
# Predicted Label: Non-sarcastic
#
# Text: படத்தோட மிகப்பெரிய மைனஸ் உதயநிதிதான். ட்ரெயிலர்ல வர்ற நாலஞ்சு ஷாட்லகூட அவருக்கு நடிப்பு வரலை.
# Predicted Label: Non-sarcastic
#
# Text: Siva sivan kjr hero trailer pakka Arjun arjunan ps hero mitran super  Saktimaan sakti 90#kids like and comment
# Predicted Label: Sarcastic
#
# Text: I am thalapathi veriyan but Thala trailar  super
# Predicted Label: Non-sarcastic
#
# Text: semma padam paakka marakathi ga guys
# Predicted Label: Non-sarcastic
#
# Text: thalaivaaaaaa!!! no words to says theriiiiiiii!!! cant wait !!!!
# Predicted Label: Non-sarcastic
#
# Text: 1 Lakh views in just 24 minutes
# Predicted Label: Non-sarcastic
#
# Text: dislike pannavangalai cut draweroda adichi anupunum...
# Predicted Label: Non-sarcastic
#
# Text: Hollywood vida tharama iruku nenakravanga yaru
# Predicted Label: Non-sarcastic
#
# Text: Poli poli poli vijay annan massssss kidu superrrrrr. Super bgm പോളി.......
# Predicted Label: Sarcastic
#
# Text: Vikram he to best hi hogi..
# Predicted Label: Non-sarcastic
#
# Text: Phaaa vera level . Thala va thala va thala
# Predicted Label: Non-sarcastic
#
# Text: அகில இந்திய இளைய தளபதி விஜய் அண்ணா ரசிகர்கள் சார்பாக , படம் வெள்ளிவிழா காண மனமார்ந்த வாழ்த்துக்கள் ...
# Predicted Label: Sarcastic
#
# Text: Pppppppppaaaaaaah appo yuththam than semma vj sethupathi love you
# Predicted Label: Sarcastic
#
# Text: Namakku thevaiyana tha namma thaa adichu vaanganum 0:37 tharam
# Predicted Label: Non-sarcastic
#
# Text: varlam varlam vaaaa varlam vaa bairavaaaaa
# Predicted Label: Non-sarcastic
#
# Text: Illaya thalapathy na mass .... Avaru mattum than mass
# Predicted Label: Non-sarcastic
#
# Text: அனைத்து சமுதாய மக்களும் ஆதரிக்கும் இப்படத்தை குறிப்பிட்ட சிலர் மட்டும் எதிர்க்க காரணம் என்ன..அவர்களே கருப்பு ஆடுகள் அவர்களின் முகத்திரையை கிழிக்க அவர்களின் மீது காவல்துறை நடவடிக்கை எடுக்கவேண்டும். படம் மாபெரும் வெற்றிபெற வன்னியனாய் வாழ்த்துக்கள்..
# Predicted Label: Sarcastic
#
# Text: Vera leval trailer.....mass overloaded...suriya anaaaa vera level....
# Predicted Label: Non-sarcastic
#
# Text: Siripu siripa varuthu to see dialoge
# Predicted Label: Non-sarcastic
#
# Text: Trailer Marana mass ah irukku and the dialogues sema
# Predicted Label: Non-sarcastic
#
# Text: Yogi b Anne  I malaysian Im roll modal u anne.I love u anne
# Predicted Label: Non-sarcastic
#
# Text: Enanga da #dev background music ah apadiyee potrukaru #harish
# Predicted Label: Sarcastic
#
# Text: Saami intha padam releasku munnadi enna Anga koopdathe appram santhosama sethu poren
# Predicted Label: Non-sarcastic
#
# Text: Trailer pathu onu purinjikiten. Payan asuran La nadiukuran appan droupathy La nadikuran. So cinema karanga enna venalum panuvanga. Namba oosaara irukanum.   Irundhalum trailer and dialogues mass ah Iruku.
# Predicted Label: Sarcastic
#
# Text: Namaku thevaiyanatha namba than adichi vankanum
# Predicted Label: Sarcastic
#
# Text: ysr surya selvaragavan combo hit like
# Predicted Label: Non-sarcastic
#
# Text: படம் வெற்றி பெற செட்டியார் சமூகம் சார்பாக வாழ்த்துக்கள்..
# Predicted Label: Non-sarcastic
#
# Text: தயவு செய்து மக்கள் திரையரங்கம் சென்று திரைப்படத்தை காணவும்!
# Predicted Label: Non-sarcastic
#
# Text: சாதிகள் உள்ளதடி பாப்பா! - குலத் தாழ்ச்சி உயர்ச்சி சொல்லல் பாவம்...  Vera level bro...
# Predicted Label: Sarcastic
#
# Text: Vijay Sethupathi Anna anna vera level 🥰🥰🥰🥰🥰
# Predicted Label: Sarcastic
#
# Text: Script matum nala iruntha mapla ne tamila kondadiruvom baahubali kgf mathiri
# Predicted Label: Non-sarcastic
#
# Text: ayyo suri mokka thanga mudiyatha
# Predicted Label: Sarcastic
#
# Text: After watching naan sirithaal we be like🤣🤣🤣
# Predicted Label: Non-sarcastic
#
# Text: Jayam ravi mass panna porean da
# Predicted Label: Sarcastic
#
# Text: கலிஃபோர்னியா காலிஃப்ளவர் சமூகம் சார்பாக திரைப்படம் வெற்றியடைய வாழ்த்துக்கள்
# Predicted Label: Sarcastic
#
# Text: Sirapana tharamana sambavam la intha padathula dha iruku each and every scene goosebumps
# Predicted Label: Non-sarcastic
#
# Text: HIGHEST KOLLYWOOD FILM TRAILER  1ST VISWASAM 1.3M LIKES 2ND NERKONDA PAARVAI 721K LIKES
# Predicted Label: Non-sarcastic
#
# Text: Thul kelapiya semma mass thala getup
# Predicted Label: Non-sarcastic
#
# Text: Sathyaama ipdi irukum nu ethir pakala semmmaa
# Predicted Label: Non-sarcastic
#
# Text: Beethoven music copy panna ilayaraja avar sonna mathiri aanmai ilathavoro.
# Predicted Label: Non-sarcastic
#
# Text: யாதவர் சமூகம் சார்பாக படம் வெற்றி பெற வாழ்த்துக்கள்
# Predicted Label: Non-sarcastic
#
# Text: Intha trailara Vida bigil trailar marana maasssa irukkum. I'm waiting to bigil trailer
# Predicted Label: Non-sarcastic
#
# Text: Marana mass uh  Thalaivar on fire..... Kola masss
# Predicted Label: Non-sarcastic
#
# Text: I am a Vijay fan but indha songa kekama iruka mudiyala. 0.30 sec thala looking like a 20  years young hero dam cute # handsome
# Predicted Label: Non-sarcastic
#
# Text: Even her sister won't like this
# Predicted Label: Non-sarcastic
#
# Text: தமிழ்நாட்டில் மிகவும் சிறுபான்மை சௌராட்டிர சமூகம் சார்பாக வாழ்த்துக்கள்...
# Predicted Label: Non-sarcastic
#
# Text: Thala and we ( thala fans) right now  Naanga thappu pandravanga illa Thappa thatti kekuruvanga
# Predicted Label: Sarcastic
#
# Text: மனமார்ந்த வாழ்த்துக்கள் நாடோடிகள் 1 போல நாடோடிகள் 2 வெற்றி பெற
# Predicted Label: Non-sarcastic
#
# Text: Diwali race winner..... Oppent aale illa sollo aahiten.......
# Predicted Label: Non-sarcastic
#
# Text: Idhan da Acting ! Kola Mass ! Saar!
# Predicted Label: Sarcastic
#
# Text: Intha trailer kum dislike poduruvan lusu koo,‍‍‍
# Predicted Label: Non-sarcastic
#
# Text: Romba alaku thalaiva nee........ thalaiva unna screenla paarthaale oru full energy warum. Lv u thalaiva...
# Predicted Label: Sarcastic
#
# Text: Trending List layae Illa Ppaaa
# Predicted Label: Non-sarcastic
#
# Text: മലയാളി..... സൂര്യ fan.... Malayali suriya fan
# Predicted Label: Non-sarcastic
#
# Text: Wow kya look hai Kangana
# Predicted Label: Non-sarcastic
#
# Text: Who are you??    THALA DA...
# Predicted Label: Sarcastic
#
# Text: namma kitta iruthu padipa mattu yeduka mudiyathu chidambaram
# Predicted Label: Non-sarcastic
#
# Text: dei new sense onakkusense illayada nee solla thevallam viswasathukku than kodida maramanda.
# Predicted Label: Non-sarcastic
#
# Text: நானும் வன்னியர் தான். எங்கள் சமுகத்தின் சார்பாக இந்தப்படம் மிகப்பெரிய வெற்றிபெற வாழ்த்துக்கள்...
# Predicted Label: Sarcastic
#
# Text: படம் வெற்றி பெற முழு ஆதரவு கொடுப்போம். அரியலூர் மாவட்டம், உதயநத்தம்   கிராமம்
# Predicted Label: Sarcastic
#
# Text: No means no entha dialogue thalaya thavara yaru sonna nallairukumnu tharayala
# Predicted Label: Non-sarcastic
#
# Text: Vijay Sethupathi Fan from Telangana
# Predicted Label: Non-sarcastic
#
# Text: Style la irukana hahaha mass dialogue
# Predicted Label: Non-sarcastic
#
# Text: Kongu Vellala Gounder sarbaga padam vettri pera valthukka
# Predicted Label: Sarcastic
#
# Text: Surya and Thalapathy fanz Hit Likzz
# Predicted Label: Non-sarcastic
#
# Text: Ellarum Equal intha world la!! Yan Neega lam eppadi Nagarigam Arivu kuda illame irukiga nu theriyala!
# Predicted Label: Non-sarcastic
#
# Text: இந்த படத்தை இயக்கிய மோகன் மனித இனத்தை சார்ந்தவனே இல்ல .சாதியால் இயக்கிய இந்த படத்தை இந்த மனித சமூகம் புறக்கணிக்க வேண்டும். அப்பொழுதுதான் இதுபோன்ற படம் மீண்டும் வராது.
# Predicted Label: Non-sarcastic
#
# Text: Ayayo bigil aprm release panratha idea iruka lokesh gaaru 🤒🤒
# Predicted Label: Non-sarcastic
#
# Text: Hollywood elements kollywood king...  Thala
# Predicted Label: Non-sarcastic
#
# Text: Cell phone towernala seththu pora sittu kuruvi manitharkalai Pali vankum Kathai
# Predicted Label: Non-sarcastic
#
# Text: Agamudayar ( Thanjavur) sarbaga padam 100 nal oda valthukal mamavalavana serupala adikanum entha padatha ekaranathakondum vitrathinga
# Predicted Label: Non-sarcastic
#
# Text: கபாலி,  காலா,  படம்  வந்த  அமைதியாக  இருந்து , அசுரன்  படம்  வந்தபோது  அனைவரும்  வாழ்த்துக்கள்  தெரிவித்து  விட்டு    இந்த  படம்  வரும் போது  எல்லோரும்  எதிர்ப்பது  ஏன்???  இனி  ஒரு  அசுரன், வந்தால்  ஆயிரம்  தேவர்  மகனும்  ஆயிரம்  திரௌபதி யும்   வர வேண்டும்
# Predicted Label: Non-sarcastic
#
# Text: Trailer super... Padam'mu super ah irukkanum
# Predicted Label: Sarcastic
#
# Text: BGM engeyo ketta mathiri irukk..  veeram
# Predicted Label: Sarcastic
#
# Text: எவ்வளவு பெயரோட மனக்குமுறல் இன்று வெளிப்படுகிறது சில குறிப்பிட்ட கும்பலால் பலபேர் பாதிக்கப்பட்டுள்ளார்கள் என்பது தெரிகிறது. என் நீண்ட கால எண்ணங்கள் வெளிப்படுகிறது நன்றிகள் பல மோகன் அவர்களே
# Predicted Label: Non-sarcastic
#
# Text: Vera level sir thala love you
# Predicted Label: Sarcastic
#
# Text: Enaku 1000mela like podanum Pola iruku but mudiyaliyaeeeee...but  Love U hip hop Tamilza🥰🤩
# Predicted Label: Non-sarcastic
#
# Text: #7 trending in Maharashtra  .Surya fans
# Predicted Label: Non-sarcastic
#
# Text: இந்த படம் தமிழ் நாட்டில் வெற்றி பெறும் இந்த படம் சொன்ன கருத்து அனைத்து உண்மையான கருத்து தன் 🤺விழுப்புரம் வன்னியர் சங்கம் வாழ்த்துக்கள்
# Predicted Label: Non-sarcastic
#
# Text: REKKA PART 2 Bt padam nalla dan irukum polaye...
# Predicted Label: Sarcastic
#
# Text: Mannu ponnu rendum onnam.. thevdiya munda.. ponnu oru usuru than unna jadam kedayathu...
# Predicted Label: Non-sarcastic
#
# Text: MAAAAASSSSSSSSSSSSSSSSSSS ra machi ....singam daaaaaaaaaa ....singam ..singam ...greatest versatile actor in india
# Predicted Label: Sarcastic
#
# Text: 90s kids ku Padaiyappaku apram oru tharamana padam
# Predicted Label: Non-sarcastic
#
# Text: Appada engge thalapathy padam vara varaikkum thala padathe pakke vendiyathu tha
# Predicted Label: Non-sarcastic
#
# Text: Lusu pasangala last ah ennaum sireka vachutenga da🤣
# Predicted Label: Non-sarcastic
#
# Text: இளைய ராஜா அவரோட இசை யா வேற படத்துல பயன்படுத்துன மட்டும் நீ அம்பலைய னு கேக்குரரு. பீத்தோவன் இசை ட்ரைலர் ல வருது ஆனா இசை இளையராஜா சொல்றக ஏனடா நியாயம் எது..உனக்கு ஒன்னு ஊருக்கு ஒன்னு
# Predicted Label: Non-sarcastic
#
# Text: Niche matt jaao saare like mang rhe h bhikhari
# Predicted Label: Non-sarcastic
#
# Text: Director  Kamal  fan pola , 96 la rajini varenu  sollave ilada.
# Predicted Label: Non-sarcastic
#
# Text: 2 years agapodhu padam yeppo ya varum
# Predicted Label: Non-sarcastic
#
# Text: Varalam varalam va varalam va Bairavaaaaaa
# Predicted Label: Sarcastic
#
# Text: Brilliant !!!! Thalaivaa !!!!!!!!!!!! Semma mass !!!
# Predicted Label: Non-sarcastic
#
# Text: Trailer அயே forward செஞ்சு பாக்க வைச்சுட்டீங்களே டா
# Predicted Label: Non-sarcastic
#
# Text: Padathode trailer nalla irukune soldrevanggelam oru like podunggo
# Predicted Label: Non-sarcastic
#
# Text: Guys make it faster..inum 8M kuda varla
# Predicted Label: Non-sarcastic
#
# Text: Ponnungaluku sport pandra maari padam ithu thalla sema weightu
# Predicted Label: Non-sarcastic
#
# Text: Wat a mannnnnnn!!!!   Rajini sir
# Predicted Label: Sarcastic
#
# Text: Yella kathalum naadaga kaathal Ila,Love panra yellaru jaathi paakurathu illa. Jathi paakura yevanum love panrathu ilaa. Oru silarukaanga ottu motha jaathiya pathi thavara padam yedukaravan manusanay ila
# Predicted Label: Non-sarcastic
#
# Text: No 1 trending in Telugu state
# Predicted Label: Non-sarcastic
#
# Text: Kekabeka nu oru short film pathruken indha madri...
# Predicted Label: Non-sarcastic
#
# Text: வர்லாம் வர்லாம் வா பைரவா என் தலைவா..
# Predicted Label: Non-sarcastic
#
# Text: சாதிகள்  இல்லையடி பாப்பா ! - குலத் தாழ்ச்சி உயர்ச்சி சொல்லல் பாவம்         - மகாகவி பாரதியார்  🥊 சாதிகள் உள்ளதடி பாப்பா ! - குலத் தாழ்ச்சி உயர்ச்சி சொல்லல் பாவம்        - திரௌபதி திரைப்படம்  🥊 உன் சமூகத்த உயரத்தனும்னா நீ நல்லா படி உழைச்சு முன்னுக்கு வா   🥊நீ உயர்ந்தா உன் குடும்பம் உயரும்   🥊உங்க ஒவ்வொரு குடும்பமும் உயர்ந்தா உங்க சமூகம் உயரும்  🥊 ஆனா சமூக குடும்பம் உயர மத்தவன் குடும்பத்தை சீரழித்த சமூகப் பிரச்சனை தான் வரும்  🟠  அதனால ஜாதி சங்கங்கள் காலத்தின் கட்டாயம் . . நன்றி
# Predicted Label: Non-sarcastic
#
# Text: Vera level na neega ayyo semmaye iruku
# Predicted Label: Non-sarcastic
#
# Text: tvaivaal aaaa aaaaaa vera level tvaivaal aaaa
# Predicted Label: Sarcastic
#
# Text: enakum matum yan deepa mari irukku
# Predicted Label: Sarcastic
#
# Text: Repeat mode for bgm.... Yuvan Vera level
# Predicted Label: Non-sarcastic
#
# Text: pwoli pwoli.  mani ratnam and ar rahman and aravind swamy. again.
# Predicted Label: Non-sarcastic
#
# Text: I like you ajit I miss you ajit
# Predicted Label: Non-sarcastic
#
# Text: Song umailaye nallarku lyrics Ku ethamari yuvan tune pannirkaru Ithu Oru emotional song.
# Predicted Label: Non-sarcastic
#
# Text: Supera iruku pakkava iruku massa iruku
# Predicted Label: Sarcastic
#
# Text: Kaithi thane daw. Intha Diwali ku
# Predicted Label: Non-sarcastic
#
# Text: Woah!!! Erumasaani Vijay... Nyk Bibian... Nd waiting for more
# Predicted Label: Non-sarcastic
#
# Text: Yella dialogue um paakum pothu open ah challenge vidura maathiri theriyuthe viswasam movie ku. Yaarukkellam appudi doubt irukku
# Predicted Label: Non-sarcastic
#
# Text: am waiting vj anna mass da
# Predicted Label: Non-sarcastic
#
# Text: no words to say ...except a name to shout .........tttttthhhhhhaaaaaaaallaaaaa
# Predicted Label: Non-sarcastic
#
# Text: My first like for vijay's movie trailer
# Predicted Label: Sarcastic
#
# Text: Innuma intha uoorula jathi la erukku🤦🤦
# Predicted Label: Non-sarcastic
#
# Text: Maranam waiting  vj64  no bigil
# Predicted Label: Sarcastic
#
# Text: Thala pola varuma enga thala pola varuma  Thala pola varuma Thala pola varuma
# Predicted Label: Non-sarcastic
#
# Text: Ippudi oru trailer vechukittu ethuku da teaser vitinga , mirattal po  visuals la stunning ah iruku
# Predicted Label: Non-sarcastic
#
# Text: Bahubaali is dead 2.0 is killer
# Predicted Label: Sarcastic
#
# Text: Mersal scene a notice pannavanga inga like pannunga
# Predicted Label: Sarcastic
#
# Text: Yebbaa poram.. Kandipaaa...
# Predicted Label: Non-sarcastic
#
# Text: Come on guys let's get it to 2 million likes!!
# Predicted Label: Non-sarcastic
#
# Text: E movie kosam waiting Telangana nunchi Danish Anna.....
# Predicted Label: Non-sarcastic
#
# Text: 🤣Full fun treat for 90s kids
# Predicted Label: Sarcastic
#
# Text: semma thaaru maara irukku. movie semma hitu
# Predicted Label: Non-sarcastic
#
# Text: Enna music vilambaram music maari irukku.but trailer nalla erukku
# Predicted Label: Non-sarcastic
#
# Text: பொண்ணும் மண்ணும் ஒன்றுதான்  அறிவில் சிறந்தோர் மண்ணை பெண்ணென்பர்  சிறியோர் பெண்ணை மண்ணெண்பர்  ஓர் உழவனுக்கு என்றுமே மண் பெண்தான் #திரௌபதி waiting......
# Predicted Label: Non-sarcastic
#
# Text: Sakthimaan fans hit likes   90S kids
# Predicted Label: Non-sarcastic
#
# Text: சிவகங்கை மாவட்டம் முக்குலத்தோர் சார்பாக படம் வெற்றி பெற வாழ்த்துக்கள் இது போன்ற படம் தமிழ்நாட்டுக்கு மிகவும் முக்கியம்  Thanks Mohan J
# Predicted Label: Non-sarcastic
#
# Text: Starting la Marvel bit and kadasila Batman bitu! 🤦‍
# Predicted Label: Non-sarcastic
#
# Text: 🤪yaralam watsapp la status la vachudu marupadiyum vanthu paakuringa🤩🤪🤩
# Predicted Label: Non-sarcastic
#
# Text: Andha 39k vum endha lusuk***** nu elarukum nalla theriyum
# Predicted Label: Non-sarcastic
#
# Text: I love Ajith Kumar Vivegam movie inki mjy bht achi lgi
# Predicted Label: Sarcastic
#
# Text: Omg thalaivaar pandey erukaraa vera level la eruku padam
# Predicted Label: Sarcastic
#
# Text: Sir please cinema ni Telugu lo dubbed chesi release cheyandi please sir
# Predicted Label: Non-sarcastic
#
# Text: NGK full form Ena ... Pls solunga
# Predicted Label: Non-sarcastic
#
# Text: Selva Anna movie nambi polam...u1 Anna music erangi adichi iruparu.....Surya sir
# Predicted Label: Non-sarcastic
#
# Text: இசை கடவுள் அய்யாவின் இசைக்காக பார்ப்பேன் அமைதியா ஆரம்பித்து அல்லு விடுது BGM
# Predicted Label: Non-sarcastic
#
# Text: Bat man kita concept ,krish kita irundhu mask , mugamoodi kita irundhu screenplay = hero 🤣🤣🤣
# Predicted Label: Non-sarcastic
#
# Text: visuvasam nelama . pakka mass entertainer
# Predicted Label: Sarcastic
#
# Text: சிவகங்கை மாவட்டம் செட்டியார், கள்ளர், மறவர், தேவர் சமூகம் சார்பாக திரௌபதி படம் வெற்றி பெற வாழ்த்துக்கள்
# Predicted Label: Non-sarcastic
#
# Text: dai views vida likes athigama irukuda?? yenda ipadi golmal panuringa..yennai arinthal BGM copied
# Predicted Label: Non-sarcastic
#
# Text: This veray happy kaapan move varlavail
# Predicted Label: Non-sarcastic
#
# Text: YouTube open panale nera nkp trailer pakuravage like podunge
# Predicted Label: Non-sarcastic
#
# Text: Viswasam teaser vara varikum treanding la irunga
# Predicted Label: Non-sarcastic
#
# Text: poi antha maavu mandaiyana kootitu vaa
# Predicted Label: Non-sarcastic
#
# Text: படம் ஓடாது னு Trailer பாக்கும்போதே தெரியுது.... இருந்தாலும் வாழ்த்துக்கள்
# Predicted Label: Sarcastic
#
# Text: Lighta adanga maaru bgm maathiri theriyuthu
# Predicted Label: Non-sarcastic
#
# Text: Ayan movieya tha ennala theaterla pakka mudiyala entha movieya semmaiya celebrate pannuva what a teaser
# Predicted Label: Non-sarcastic
#
# Text: ennanga da irumbuthirai part 2 va
# Predicted Label: Non-sarcastic
#
# Text: Na Vijay Anna fan Bigil,Kaithi, Randhum padhamu papan
# Predicted Label: Non-sarcastic
#
# Text: 2.05...ஏய்....! இது 96 யார ஏமாத்துரிங்க...!!! Origional...
# Predicted Label: Non-sarcastic
#
# Text: Yuvan music maassssss love you yuvan
# Predicted Label: Sarcastic
#
# Text: Vera lvl  Thala version
# Predicted Label: Non-sarcastic
#
# Text: Puthupettai in thala dhanush son baby kokki kumar is back maathiri vera level i love dhanush
# Predicted Label: Non-sarcastic
#
# Text: Thalaivara vanga vanga  kola mass irukku... Mor(10.00) mani showkku kandippa unka tharasinam tha...
# Predicted Label: Non-sarcastic
#
# Text: Intha padamavadhu solra datela release pannunga pls
# Predicted Label: Non-sarcastic
#
# Text: I think Akshara ku pair aa Dhuruv Vikram nadachirukkalam
# Predicted Label: Non-sarcastic
#
# Text: Nasam thara nasam thala i love u
# Predicted Label: Non-sarcastic
#
# Text: Surya , Sai Pallavi and Rakul Preet Singh
# Predicted Label: Non-sarcastic
#
# Text: *tha theliva plan pottu eduthu irukka padatha idhukumela evanum caste vittu caste love pana kudadhunu idhuku vera support pandra maari comment pannitu irukinga🤦‍ already  Inga jaathi veachi niraya prachana poitu irukku pudhusa vera start pandringa
# Predicted Label: Non-sarcastic
#
# Text: It's looking like a lifeless statue
# Predicted Label: Non-sarcastic
#
# Text: Wtf! Epudi da views Vida likes adigama iruku!!!
# Predicted Label: Non-sarcastic
#
# Text: Makkalta kaitatu vaangae vivasayatha base panni Padam edukirainga idanala Tamil cinemavukum use illa vivasaigalukum use illa
# Predicted Label: Non-sarcastic
#
# Text: Idhu '96 uh yaara yemathuringa....
# Predicted Label: Non-sarcastic
#
# Text: Ennaya teeser apram triller laye ippudi miraturinga padam vantha vera level pola
# Predicted Label: Non-sarcastic
#
# Text: 1 week kula 10 Million varanum
# Predicted Label: Non-sarcastic
#
# Text: gommala makku kuuthi 1996 la enga da puthiya thalaimurai irunthuchu lusu kuthigala ithukku support vera
# Predicted Label: Non-sarcastic
#
# Text: un peru dhan nee sona mathiri iruku da musma
# Predicted Label: Non-sarcastic
#
# Text: dislike potavanlam..... Setthuru..... summava Bigil team late release ku paechu vaarthai nadathinaanga... Trailer therkidhu.. Sure shot saravedi
# Predicted Label: Non-sarcastic
#
# Text: Ithu Ena BigBoss promo va da like comment nu vilayaditu irukinga 🤣🤣
# Predicted Label: Non-sarcastic
#
# Text: கொங்கு பெண் குழந்தைகள் பார்க்க வேண்டிய படம்...
# Predicted Label: Sarcastic
#
# Text: Enna da 2days ku mela aguthu innum 1miliyan like varala. Eppo than varum 3 month apram ahh..
# Predicted Label: Non-sarcastic
#
# Text: Wow 5m views and 385k likes in a day
# Predicted Label: Sarcastic
#
# Text: Sunni mavattathula irunthu kena pundaigal sarba vazhthukkal
# Predicted Label: Non-sarcastic
#
# Text: Wt a movi wt aaaaaa moviii.......superb superb....
# Predicted Label: Sarcastic
#
# Text: Gommala marana kaatu kaatitan trailer la ye
# Predicted Label: Non-sarcastic
#
# Text: 0:45 Chiyaan Deadly look Ungaluku vayase aagadha
# Predicted Label: Non-sarcastic
#
# Text: தெற்கு பக்கம் இப்படி பல நாடக காதலினால் பாதிக்க பட்டு கண்ணீர் விடும் நாடார் சமுதாயம் மக்கள் சார்பாக  இந்த உண்மைக்கதை வெற்றி பெற வாழ்த்துகள்
# Predicted Label: Non-sarcastic
#
# Text: செம்ம சியான  மரண Waiting for kadaram kondon movie
# Predicted Label: Non-sarcastic
#
# Text: tamil cinema la ipdi oru padam vandhu rombva naal achu da saaami summa aracha mavaa arachini copy pani padam edukranunga
# Predicted Label: Non-sarcastic
#
# Text: Semma trailer...  oru nalla entertain movie iruku
# Predicted Label: Non-sarcastic
#
# Text: mass  class Thalaiva Vera evanum ila
# Predicted Label: Sarcastic
#
# Text: Trailer full ah dark ah irruku... Konjam colourfull ah iruntha nalaa irrujum
# Predicted Label: Non-sarcastic
#
# Text: Unlike ah pathaley theridhu Anil s velanu  katharunga Da kathariye savunga Da
# Predicted Label: Non-sarcastic
#
# Text: Paaah talaivaaaaaa style mannan iz back
# Predicted Label: Non-sarcastic
#
# Text: brammaaandatha paarthu brammippaaaagardhu yenbadhu yidhuthaaanoa........woooooooowwwwwww many times watched but still want  to watch....hats off to d team 2.0
# Predicted Label: Sarcastic
#
# Text: Aaudha yezhuthu aprm massive suriya va stylish suriya va aprm different attitude oda pakuran tq selva & U1
# Predicted Label: Non-sarcastic
#
# Text: All the best south superstar karnataka stylish superstar, badhshaa kichcha sudeep anna biggest fans 🥰🥰🥰🥰
# Predicted Label: Sarcastic
#
# Text: வன்னியர் குல சத்திரியர் சார்பாக இந்தப் படம் வரலாறு காணாத அளவுக்கு ஒரு வெற்றி பெற வாழ்த்துகிறேன்.......... வீர வன்னியன்
# Predicted Label: Non-sarcastic
#
# Text: JM rav : chinna vayasula  oru aerila kulipomla anga kootitu poda Yogi B : adhu Mela dhanda nadanthutu irukom
# Predicted Label: Non-sarcastic
#
# Text: Soori come back irundha nalla irkum
# Predicted Label: Non-sarcastic
#
# Text: Daii ungaluku Ajith Vijay thavira Vera evanum theriyathada in padam trailarku avnaga padatha ean da copy poduringa yosinga da puthusa ethavathu chiiiii....thiii
# Predicted Label: Non-sarcastic
#
# Text: இங்க கமெண்ட் போட்டவங்க எத்தனை பேரு படிச்சிருக்கீங்க ஜாதிகள் இல்லையடி பாப்பா ஜாதிகள் இல்லையடி பாப்பா ஜாதி இருக்குன்னு வெச்சுக்கோங்க எத்தனை பேரு ரஞ்சித் படையெடுப்பதற்கு எதிர்ப்பால் போட்டு இருக்கீங்க உங்க மனசை தொட்டு சொல்லுங்க ஜாதி வன்மத்தோடு கமெண்ட் போட்டு இருக்கீங்களா இல்ல இந்த படம் நல்ல படம் என்று எண்ணியே கமெண்ட் போட்டு இருக்கீங்களா என்னன்னு தெரியல எதுவா இருந்தா நல்ல படம் நல்ல வரவேற்போம் அவ்வளவுதான். ஆனா ஒவ்வொருத்தனும் வன்மத்தோடு கமெண்ட்டா இருந்தால் உங்களை கொள்ளும் உங்கள சுத்தி இருக்குற உங்களையும் கொல்லும் அதை மட்டும் நீங்க மனசுல வச்சுக்குங்க
# Predicted Label: Non-sarcastic
#
# Text: Wow mind blowing singampuli sira kuda seriousa katirukanga
# Predicted Label: Non-sarcastic
#
# Text: Omg..oru trailer paathu enjoy panadhu idhan 1st time.
# Predicted Label: Non-sarcastic
#
# Text: Rajini - karthick subbu wow k wow
# Predicted Label: Non-sarcastic
#
# Text: 1:58 idhu yarukko solra mari irukae
# Predicted Label: Non-sarcastic
#
# Text: Karthi sir  tha daaaaaaaa indha diwali
# Predicted Label: Non-sarcastic
#
# Text: Theri Vera....  Mega hit 2016.... Rajini +Kamal =Vijay  Shanker +rajamahli = atlee...
# Predicted Label: Non-sarcastic
#
# Text: ஜாதி வெறி பிடிச்ச நாய்ங்களா., இப்படம் நாசமா போக வாழ்த்துக்கள்...
# Predicted Label: Non-sarcastic
#
# Text: Jathi irukka kudathu than ana athuku nu pre planned ah organised ah seiypadum intha Mari nadaga kadhal  velai ah la yethuku mudiyathu
# Predicted Label: Non-sarcastic
#
# Text: ஒரு தகப்பன் தன் பிள்ளைக்கு சொல்லி தரக்கூடாதது  அரசியல் மட்டுமே......நம் நாட்டில் களைபுடுங்க வேண்டியது அதிகமாக உள்ளது விழித்துக்கொள் இளைஞர்களே
# Predicted Label: Non-sarcastic
#
# Text: S3 teaser last dialogue semma chance illa
# Predicted Label: Non-sarcastic
#
# Text: ongalaku kadisi varaikum thupakki dan daww...adhunala dan vj kuda trailer kadaisile thupakki aa katraru...idhu kuda ongalaku puriyala....
# Predicted Label: Non-sarcastic
#
# Text: 44k views 67k like ennada pannivachirukiga
# Predicted Label: Sarcastic
#
# Text: Mokka pathi vijay looose thevidiya vijay
# Predicted Label: Non-sarcastic
#
# Text: Taramaana sambavam pongalukku irukku le
# Predicted Label: Sarcastic
#
# Text: ஜாதி தான அடங்கிட்டு போனாலும், சினிமாவும், சில அரசியல் வாதிகளும் தூண்டி விட்டு குளிர் காய்வாங்க..
# Predicted Label: Non-sarcastic
#
# Text: Mass iruku eppo entha padam varum I love u vikram
# Predicted Label: Sarcastic
#
# Text: Kangana look like an animated panda
# Predicted Label: Non-sarcastic
#
# Text: Konar sarpaga valthu thiruma oonoda Katha ethoda over da 🤣🤣🤣🤣
# Predicted Label: Non-sarcastic
#
# Text: அடுத்த முத்தையா டைரக்டர். அண்ணன் மோகன் அவர்களுக்கு மனமார்ந்த நன்றி. மேலும் இந்த படம் முழு வெற்றி அடைய வாழ்த்துகிறோம்
# Predicted Label: Sarcastic
#
# Text: Hope our tamil.movies must b vera leval
# Predicted Label: Non-sarcastic
#
# Text: Aana onnu da.. indha modi(BJP) aatchila makkalukku nalladhu nadandhuto illaiyo bt most film directors kku ungea aarchiyea vachi nalla story kidachirukku.. bharat matha ki jai..
# Predicted Label: Non-sarcastic
#
# Text: Thala and yuvan combo vera level
# Predicted Label: Non-sarcastic
#
# Text: Innum pink trailer pakkathave  ellam pathutu vanthu comment pannu.....
# Predicted Label: Non-sarcastic
#
# Text: Kitne kilo make-up lagaya hai face pr...... Emoticon to dekhne dete be.... Agar final movie me bhi yahi haal raha to  Kya matlab rahega kangna jaisi actress ko cast kar kr....
# Predicted Label: Non-sarcastic
#
# Text: Kelatu Kungi ajith avan poola seppu santhi sotta thala
# Predicted Label: Sarcastic
#
# Text: Va Va Va varlam Va bairava.
# Predicted Label: Non-sarcastic
#
# Text: Views and likes check panna vantha D fans like pannunga
# Predicted Label: Non-sarcastic
#
# Text: SK Anna fans hit like here
# Predicted Label: Sarcastic
#
# Text: Thala na Suma va Vera level trailer
# Predicted Label: Non-sarcastic
#
# Text: ரஜினி சாரை பத்தி பேசினா மட்டும்தான் உங்க படத்துக்கு பிரமோஷனும் கிடைக்கும் அதனாலதான் நீங்க டிரைலர் கிண்டல் செய்றாங்க உங்களுக்கெல்லாம் வேற வேலையே இல்லை
# Predicted Label: Non-sarcastic
#
# Text: Trailer Maatraan second of mari iruku. Movie vera mari irubtha nalarukum...padam vetri pera vaazhthukkal.
# Predicted Label: Sarcastic
#
# Text: Comments eathanum adha Vida like kandipa eariyae aganum pa 1.5m cross pananum
# Predicted Label: Non-sarcastic
#
# Text: padam patuthu trailer pakuruvunga like podunga
# Predicted Label: Non-sarcastic
#
# Text: மகிழ்ச்சி. . வாழ்த்துக்கள் படம் மிகப் பெரிய அளவில் வெற்றி பெறும். கடைசி வசனம் அருமை. இன்னும் 16 வருடம் போனாலும் நான்  அரசியலுக்கு வருவேன் தான் சொல்லுவான். ஆனால் இப்போது எல்லாம் வர மாட்டார். வரவும் வேண்டாம்.
# Predicted Label: Sarcastic
#
# Text: paaka thana pora indha kaali yoda aatatha!
# Predicted Label: Sarcastic
#
# Text: Karunikar pillai sarbaga all the best
# Predicted Label: Non-sarcastic
#
# Text: தயவு செய்து இந்த படத்தை திரையரங்கில் பார்த்து இது போன்ற உண்மையை உடைக்கும் படங்களுக்கு ஆதரவு தரவேண்டும் நாம் சபாஷ் மோகன். உடையார் (நத்தமன்னர்) சமூகம் சார்பாக வாழ்த்துக்கள்
# Predicted Label: Non-sarcastic
#
# Text: From 0: 48 #U1 bgm start
# Predicted Label: Non-sarcastic
#
# Text: Wow rajini and vijay sethupathi sprr waiting
# Predicted Label: Sarcastic
#
# Text: மிரட்டல் வேர லெவல்.மதுரை தல ரசிகர்கள் சார்பாக வாழ்த்துக்கள்
# Predicted Label: Sarcastic
#
# Text: Super ...... Nice ..... Amazing Movie ...
# Predicted Label: Non-sarcastic
#
# Text: Peruku pinaadi Jadhi pera edhuthaa Jaadhi oziyum nu solli valatha mutaa thanam laam maara inda padam thodaka pulliyaa amayattum...Samooga nallinakathudan vaazvom....
# Predicted Label: Sarcastic
#
# Text: PPaaa .. namma kannu nammakitta illa.. Ezhundhaal malayaai ezhuvom.... Waiting..... dote
# Predicted Label: Sarcastic
#
# Text: Semma thala nega vara level poga evanum nika mudiyathu young pakathula
# Predicted Label: Non-sarcastic
#
# Text: Nee Januaryil viriyumo.... (Malayalam Song) .... Istamullavar Adi like
# Predicted Label: Non-sarcastic
#
# Text: Ee dislike kondu ningal enthu needunnu
# Predicted Label: Non-sarcastic
#
# Text: Massssssssss teaser lets make it 12 million
# Predicted Label: Non-sarcastic
#
# Text: Verra level chance a illa
# Predicted Label: Non-sarcastic
#
# Text: Ayyo like button one dhana irukku na ena panuven
# Predicted Label: Non-sarcastic
#
# Text: Naraya Peru vivegam trailer dislike pannanumne pakkaranka oru nimisham dislike kavida likes athikam so
# Predicted Label: Non-sarcastic
#
# Text: Enna panna porom sweet sapda porom petta paraak
# Predicted Label: Non-sarcastic
#
# Text: A MAGNUM OPUS SHORT FILM   FI SHORT FILM MAKING IN ZERO BUDGET
# Predicted Label: Sarcastic
#
# Text: Indha olagame unna edhirthalum..... Nee thoothitte thoothitte nu, un munnadi ninnu alarnalum...... Adha neeya othukara varaikum.. .. Evannalum..... Engeyum..... Eppoyum..... Unnai jeikamudiyadhu.... Never... ever ..... Give up!!!!!!
# Predicted Label: Sarcastic
#
# Text: Movie la oru sila scene ha partha telugu movie rangasthalam movie mari eruku but parkalam movie release apo
# Predicted Label: Non-sarcastic
#
# Text: I like this song   Ossssam movie
# Predicted Label: Non-sarcastic
#
# Text: varalam varalam va bairavaa. superb. theri baby
# Predicted Label: Non-sarcastic
#
# Text: I'm vijay fan but equally like ajith sir to
# Predicted Label: Non-sarcastic
#
# Text: Make it 10m in 2-3 days 🤗
# Predicted Label: Non-sarcastic
#
# Text: Director Korean series Rombo parparnu nenaikraen
# Predicted Label: Non-sarcastic
#
# Text: #Thala mass da Padam vetri pera #Thalabathy rasiganin valthukkal
# Predicted Label: Non-sarcastic
#
# Text: Paaaaah excepting more thala acting pichutenga ......padam tharu Maru...pink ah minjurum polaeya..... love you thank...by thalapathy fan
# Predicted Label: Non-sarcastic
#
# Text: dei TEEJAY thay***!! naduchirukaya da b**du!
# Predicted Label: Sarcastic
#
# Text: Acting king surya v level
# Predicted Label: Sarcastic
#
# Text: Vayasanalum unga style azhagum innum marala.... Thalaiva roxkzzzzzz
# Predicted Label: Non-sarcastic
#
# Text: Mrng wake up anathum trailer paika Vantha vanka like poduinka
# Predicted Label: Non-sarcastic
#
# Text: மிக பெரிய வரலாற்று வெற்றி படமாக அமைய வாழ்த்துக்கள்
# Predicted Label: Sarcastic
#
# Text: s3 teaser in 3 weeks 7.5million views but bairavaa got 10million views in 3 weeks
# Predicted Label: Non-sarcastic
#
# Text: Harris jayaraj  is back
# Predicted Label: Sarcastic
#
# Text: Enna Da idhu Vijay ya ipdi pantaanga... Paavigala nnu nenachi mudikala adukulla vachitaanga Ajith scene... Appa saami
# Predicted Label: Sarcastic
#
# Text: superpa ipti oru teasere holliwood movile koode pakkele ppa
# Predicted Label: Non-sarcastic
#
# Text: Masss kae Innom masss eatthi vitrukkaan Anirudh... Marana maasss trailer... Enna style yaa... Pakka masssssss
# Predicted Label: Non-sarcastic
#
# Text: Itha tha naanga thalaivar ta irunthu ethir paakkuro. THALAIVAAAAAAAAA marana mass kaattringa ponga...
# Predicted Label: Non-sarcastic
#
# Text: Then Kekka Bekka Kekka Bekka shortfilm...Now Naan sirithaal Big Film... Congrats Team
# Predicted Label: Sarcastic
#
# Text: Kola mass....bgm maranam... Thalapathi looks osm...
# Predicted Label: Non-sarcastic
#
# Text: maththavangaluku thala yaarunn ippa theriyim, thala fance yaaarunnum ippa theriyum. naanga peeniks parava da, thala sixpak. paakka readyaa? vivegam film ma therikka vidalama.)
# Predicted Label: Non-sarcastic
#
# Text: 10k comment daa  kabi nesh bro aasai tiinthiricha
# Predicted Label: Non-sarcastic
#
# Text: semma mass super star nenga vera level sir
# Predicted Label: Non-sarcastic
#
# Text: Innaikku night ey 13 million views ah kannala parkanumnu solravanga like podunga
# Predicted Label: Non-sarcastic
#
# Text: Ultimate star Ajithkumar vera level  MASS
# Predicted Label: Non-sarcastic
#
# Text: Thala pola varuma thala pola varuma thala super
# Predicted Label: Non-sarcastic
#
# Text: Nee thaan ennn Ammma&  Apppa thalavaaa
# Predicted Label: Sarcastic
#
# Text: ஒவ்வொரு வினைக்கும் ஓர் எதிர்வினையுண்டு...என்னுடைய மனமார்ந்த வாழ்த்துக்கள் சகோதரர்  மோகன் அவர்களுக்கு....இப்படி ஒரு படம்வராதா என ஏங்கிய கோடிக்கணக்கான மக்களில்  நானும் ஒருவன்....வாழ்க நாடு...வளர்க கலைகள்...
# Predicted Label: Non-sarcastic
#
# Text: Thalapathy dialogue delivery.. chance'e illa.. vera level!
# Predicted Label: Non-sarcastic
#
# Text: Vijay fans support eppovum iruku ungalukku surya fans
# Predicted Label: Non-sarcastic
#
# Text: che cuándo van a empezar a hacer subtitulados en español ??? No se entiende nada!!!
# Predicted Label: Non-sarcastic
#
# Text: Nammakitta kaadu irndha eduthukuduvanunga...kaasu irndha  pudingikuvanga...aana padippa yaaru edthukkamudiyadhu.....
# Predicted Label: Non-sarcastic
#
# Text: Friend du na Facebook la like koodukura friend nu nenachiya da....lifaye kudukanum da
# Predicted Label: Non-sarcastic
#
# Text: வாழ்த்துகள் நம்பிக்கை துரோகம் பண்ரவனையும் துரோகம் பண்ரவனையும் பன்றது தப்பு இல்ல மரணம் தீர்வு ஆகாது
# Predicted Label: Non-sarcastic
#
# Text: Uvan shankar raja bgm pattaya kilapputhu..!
# Predicted Label: Non-sarcastic
#
# Text: Nethaan ennoda thala unna ethirtha velum kola
# Predicted Label: Sarcastic
#
# Text: #ngk on may 1 #kaapan on diwali #soorarai potru on 2020
# Predicted Label: Non-sarcastic
#
# Text: Yampa vijay enna kariyam pa pandraa..
# Predicted Label: Non-sarcastic
#
# Text: நான் வணங்கும் முப்பாட்டான் சிவசாம்பவனிடம் வேண்டுகிறேன் ..படம் வெள்ளிவிழா காணா....
# Predicted Label: Sarcastic
#
# Text: Vadachennai ku aprom oru come back pa
# Predicted Label: Non-sarcastic
#
# Text: dai bgm a enaada panni vachurukeenga....  padam worstunu yaaravadhu sonna aadhuku karanam bgm dhan..... producer director actors ellathaiyum bgm keavalam aakiduchu..... thu  thu thu....
# Predicted Label: Sarcastic
#
# Text: Enada ithu views 58k likes 98k ppidrukku... lokesh rocks
# Predicted Label: Sarcastic
#
# Text: Thalaaaaaaaaaaaaa...... wow fight scene iruku.... namaku treat iruku
# Predicted Label: Sarcastic
#
# Text: இரும்புக் கோடை முரட்டு சிங்கம் feel இருக்கே🤔
# Predicted Label: Non-sarcastic
#
# Text: Bigil Movie Ku sangu dha ooo ooo
# Predicted Label: Non-sarcastic
#
# Text: Naa than first nu ninacha kajal dialogue
# Predicted Label: Non-sarcastic
#
# Text: Marana mass song expect panni disappointed aanavanka like pannunka ..
# Predicted Label: Non-sarcastic
#
# Text: Adai trailer yeah cut dhaan adheayeah skip panni paaka vaikireingaleayda
# Predicted Label: Non-sarcastic
#
# Text: திண்டுக்கல் மாவட்ட வெள்ளாளர் வேளாளர் சமுதாயம் சார்பாக படம் மாபெரும் வெற்றி அடைய   வாழ்த்துக்கள்...
# Predicted Label: Non-sarcastic
#
# Text: Surya anna is fair  podu thakida thakida
# Predicted Label: Sarcastic
#
# Text: Romba kastapattu eduthurukanga paathaley theriyuthu unga ThalaThalapathy fan war la konjam thalli vachutu padatha theater la poi paarunga da...
# Predicted Label: Non-sarcastic
#
# Text: தலைவா நீங்க வாங்க தலைவா இனி எவனாவது ஆடுறானானு பாப்போம்
# Predicted Label: Sarcastic
#
# Text: That Bgm is lit... Marana waiting thalaivaaaaa
# Predicted Label: Non-sarcastic
#
# Text: Jaathi vendamnu thanda padame varuthu... Appavum avavan jaathiya vachu thanada vaalthu solringa.. Karumam...poi nalla Aani pudungunga ponga...
# Predicted Label: Non-sarcastic
#
# Text: Orutthar mela unga viswasatha kaatradhukaha innoruthara yaen asingapaduthureenga
# Predicted Label: Non-sarcastic
#
# Text: சேனைத்தலைவர் சமுதாயம் சார்பாக படம் வெற்றி பெற வாழ்த்துக்கள்
# Predicted Label: Sarcastic
#
# Text: Thala fans like potu tu poge
# Predicted Label: Non-sarcastic
#
# Text: Thala da vera yevann daaaaa ..He is gonna RAGEEE !!!
# Predicted Label: Non-sarcastic
#
# Text: சூப்பர்  மிகப்பெரிய வெற்றி பெரும் தலைவா...
# Predicted Label: Non-sarcastic
#
# Text: Suriya I one man king movie kaga I am waiting sir is super hero
# Predicted Label: Non-sarcastic
#
# Text: பாட்டாளி மக்கள் கட்சியின் விழுப்புரம் வடக்கு மாவட்டம் ஒலக்கூர் ஒன்றியம் மேற்கு சார்பாக திரைப்படத்தை வெற்றியடைய செய்வோம் என்பதை உறுதி அளிக்கிறோம்
# Predicted Label: Sarcastic
#
# Text: Romba naal kaluchu ajithu mass video pakaren... Vera level...
# Predicted Label: Non-sarcastic
#
# Text: Velangirum da.  Endha rendu nainga tholla thanga mudiyala da.   Dhayavu senji neengalam unga orlayae sethu poirunga da. Vera endha oruku vandhuradhinga. Avainga oru picha neenga oru echcha. Edhula evan periyavanu padam vera edukurainga🤣
# Predicted Label: Sarcastic
#
# Text: Ajithku aprm support pannalam
# Predicted Label: Non-sarcastic
#
# Text: Last Dialouge la Thala ya  Adikuringala da Kaithi Team   Atha Yenda NeYaBa PaduThuRiNga
# Predicted Label: Sarcastic
#
# Text: No 1 trending in malaysia
# Predicted Label: Non-sarcastic
#
# Text: புதுக்கோட்டை முக்குலத்தோர்  சார்பாக படம் பிரம்மாண்ட வெற்றியடைய வாழ்த்துக்கள்!
# Predicted Label: Non-sarcastic
#
# Text: 1:18 bgm feels like Nkp Va mothi Paru
# Predicted Label: Sarcastic
#
# Text: Thala epo vum   masss tha
# Predicted Label: Non-sarcastic
#
# Text: Thalapathy 64 ku wait pandravaga like poduga
# Predicted Label: Sarcastic
#
# Text: கன்னியாகுமரி மாவட்டத்தில் இந்த நாடக காதல் ரொம்பவே நடக்குது
# Predicted Label: Non-sarcastic
#
# Text: Va Thalaiva va Thalaiva pandithevarin valthukkal
# Predicted Label: Non-sarcastic
#
# Text: bro youtube I'll froud viewers pannamudiyathu purinju pesanga
# Predicted Label: Non-sarcastic
#
# Text: Surya fans ku oru periya treat irukku
# Predicted Label: Non-sarcastic
#
# Text: Кто з руских ставте лайк на комент
# Predicted Label: Sarcastic
#
# Text: therikuthu teaser Surya anna masss nu solravanga like...
# Predicted Label: Non-sarcastic
#
# Text: Ohh ellam penda பரம்பரையும் இங்க தான் இருக்கீங்களா
# Predicted Label: Sarcastic
#
# Text: TOO  MUCH OF   CARTOON  ANIMATION  AND  EDITING
# Predicted Label: Non-sarcastic
#
# Text: இசை மிகவும் அருமையாக உள்ளது. வசனம் மிகவும் நன்றாக உள்ளது.  எங்கள் உணர்வுகளின் வெளிபாடு  திரைப்படம் மாக  வருகிறது. இயக்குனர் அவர்களின் இந்த படைப்பு . பலருக்கு பாடம் மாக அமையும் . திரௌபதி  டீம் இக்கு எனது வாழ்த்துக்கள் அனைவரும் திரையரங்கு சென்று பாருங்கள் . சோழநாடு . முக்குலத்தோர்  சார்பாக  வாழ்த்துக்கள்....
# Predicted Label: Sarcastic
#
# Text: THALA ACTING MASS VERA LEVEL VIVEGAM
# Predicted Label: Sarcastic
#
# Text: howw like + dislike > total views. Cheater
# Predicted Label: Non-sarcastic
#
# Text: don't compare bairavaa and s3 bairavaa is mass marana mass a
# Predicted Label: Sarcastic
#
# Text: Vaani fans like panuga Rithika Singh fan like panuga  Sethu fan like panuga nu solrangalae ,evanachu trailer epti irukunu solrana pathiya...
# Predicted Label: Non-sarcastic
#
# Text: Vikram =Hardwork Never ever give up(Gibran music )
# Predicted Label: Non-sarcastic
#
# Text: Next stop at 15M views n 600K+ likes
# Predicted Label: Non-sarcastic
#
# Text: Anyone after bigil trailer. Kaithi - like Bigil - comment
# Predicted Label: Non-sarcastic
#
# Text: Gethu Da padathuku nanga nikurom kooda
# Predicted Label: Non-sarcastic
#
# Text: தரமான எதிர்பார்த்த ஒன்று!விஸ்வகர்மா சமூகம் சார்பாக வெற்றி அடைய வாழ்த்துகிறோம்! @சமதர்மம் என்பது எல்லா மனிதக் குழுக்களும் இணைந்து வாழ்வதே! மேல் நடு கீழ் என்பது இயற்கைத் தன்மை!
# Predicted Label: Non-sarcastic
#
# Text: மூன்றாம் கலைஞர் அண்ணா பேன்ஷ் லைக் தெறிக்கவிடுங்க
# Predicted Label: Non-sarcastic
#
# Text: Kangana ranaut is super talented  yeh to mana padega
# Predicted Label: Sarcastic
#
# Text: 1996 ha ha ha . Waiting to watch
# Predicted Label: Sarcastic
#
# Text: padam vetri pera Vazthukal
# Predicted Label: Non-sarcastic
#
# Text: Trailer payangarama irukku movie ku waiting
# Predicted Label: Non-sarcastic
#
# Text: தருமபுரி மாவட்ட தீரன் சின்னமலைகவுண்டர் பேரவை சார்பாக வாழ்த்துக்கள்
# Predicted Label: Non-sarcastic
#
# Text: Teaser Pakka Mass Thalaivaaa <3 <3
# Predicted Label: Non-sarcastic
#
# Text: Bollywood never make movies like Kollywood.
# Predicted Label: Sarcastic
#
# Text: Indha video va pakkum podhu yaru like takku potta
# Predicted Label: Non-sarcastic
#
# Text: Nalla velea thalapathiya mattum thaan intha padathulea kaatuniganaa kadupu airupan nalla velea enga kadavul thalayaiyum kaati irrukinga itthukagavea padathuku povom..
# Predicted Label: Non-sarcastic
#
# Text: Idhu dhan Abdul Kalam sir sonna 2020 pola comments fulla gubeer dhan
# Predicted Label: Non-sarcastic
#
# Text: இந்த ஆண்ட சாதி ஆமைகள் தொல்ல comment section la தாங்க முடியல நா தேவன்டா நா கவுண்டன்டா நா வன்னியன்டா அப்படினு comment போட்டு saavadikiraanuga
# Predicted Label: Non-sarcastic
#
# Text: வாழ்த்துகள் நண்பரே.. சொல்ல மறந்த இல்ல பலபேர் சொல்ல பயந்த கதை இது...
# Predicted Label: Non-sarcastic
#
# Text: Yenda malamatu punda unaku புரட்சி panradhuku வேர பிரச்சனை இல்லையா
# Predicted Label: Non-sarcastic
#
# Text: Super Super    dhool  dhool Ma
# Predicted Label: Sarcastic
#
# Text: Yeppa.. Trailer ra marana comedy ya irruke🤣🤣..Padam yeppadi irrukomoo
# Predicted Label: Non-sarcastic
#
# Text: 1st like and 1st comment
# Predicted Label: Non-sarcastic
#
# Text: Super Hit Trailer Love From pakistan Chiyaan Vikram Sir FanS Hit Like Here
# Predicted Label: Non-sarcastic
#
# Text: If do e pick PC e hook
# Predicted Label: Non-sarcastic
#
# Text: Marana masss in six pack amazing
# Predicted Label: Non-sarcastic
#
# Text: VANTHUTHENU SOLLU THIRIMPI VANTHENU 20 VARUCHUTHAKU MUNNADI EPIDI PONNENU APIDIYE THIRIMPI VANTHENU SOLLU PETTA DA... MARANA MASS DA
# Predicted Label: Non-sarcastic
#
# Text: 90s vs 2k.. semma movie pole
# Predicted Label: Non-sarcastic
#
# Text: 15 minutes la 415k views aaaaaa ?........       SATHYAMAAA MARANA MAAASSSS
# Predicted Label: Sarcastic
#
# Text: உதயநிதிக்கு நடிப்பு வரலனு சொல்ரவங்க லைக் போடுங்கள் ...
# Predicted Label: Non-sarcastic
#
# Text: Kangana looks like jaylalita's wax figure
# Predicted Label: Non-sarcastic
#
# Text: inu evlo neram venalum thoongama pakalam .thala oda 1.5 years harkwork ku  #thalareadytorage
# Predicted Label: Non-sarcastic
#
# Text: இப்படி ஒரு படம் வந்திற்கு மகிழ்ச்சி அடைகிறேன்
# Predicted Label: Non-sarcastic
#
# Text: inaikulla 6 millian viws varuma ???
# Predicted Label: Non-sarcastic
#
# Text: naa yarengrathu epovea naa mudiv panratilea.. en etirlea  nilkanavangea mudiv panrea.. avangalku naan nabana elea ethirya nu. thala<3
# Predicted Label: Non-sarcastic
#
# Text: Theri!!! Semma Theri!! JOSEPH kuruvilla & VIJAY kumar are just awesome kumar
# Predicted Label: Non-sarcastic
#
# Text: Naan oru ajith fan. Trailer nalla irukku nu oolu lam vida matten. But unmayile I am a thala fan. Trailer is good. Vazthukal...
# Predicted Label: Non-sarcastic
#
# Text: Hope it shine in big screens
# Predicted Label: Non-sarcastic
#
# Text: Pakka mokka movie 2019  Surya  Unga 2d  after 0d than
# Predicted Label: Non-sarcastic
#
# Text: Xin chào tất cả mọi người
# Predicted Label: Non-sarcastic
#
# Text: ***thaaa  BGM vera level mass ....
# Predicted Label: Non-sarcastic
#
# Text: மயிலாடுதுறை சம்புவராயர் வகையாறாவோடு திரையரங்கு வந்து பார்ப்போம்...  நெஞ்சம் நிறைந்த வாழ்த்துக்கள்.
# Predicted Label: Non-sarcastic
#
# Text: thala veriyans. Maddum oru like poddu vidunga bro.
# Predicted Label: Non-sarcastic
#
# Text: Inga comment panra nallavanga ellam  Cha Cha Intha kaalathula yaar cast pakura nu sonna uthamanga dhana. 🤣🤣 Yov aiiyaa Apj kanava pathi Yosipom ya.
# Predicted Label: Sarcastic
#
# Text: thaviva waiting thalaiva  va va va bairava
# Predicted Label: Sarcastic
#
# Text: Joaquin Phoenix : Dei Sundar C, yen padathayum Copy Adichitiyada
# Predicted Label: Non-sarcastic
#
# Text: low caste pasangala pathina padama  Avlova hit agathu
# Predicted Label: Sarcastic
#
# Text: 1:06 gibran Vera level
# Predicted Label: Sarcastic
#
# Text: 1:55 sema thala super ah sonninga
# Predicted Label: Non-sarcastic
#
# Text: Thala  kola mass
# Predicted Label: Non-sarcastic
#
# Text: Pa. Ranjith போன்ற இயக்குனர் ah... சரியான படம் #draupathi சாதி படம் அல்லா பெண்கள் மானம் காக்க வந்த நீதி படம்
# Predicted Label: Non-sarcastic
#
# Text: Bgm yaaru Ilayaraja sir a....bangam pa
# Predicted Label: Non-sarcastic
#
# Text: Mersal & viswasam seance ennada panni vechurukinga.. sema  🤣🤣
# Predicted Label: Sarcastic
#
# Text: Nenu ee movie chusanu nice movie
# Predicted Label: Non-sarcastic
#
# Text: 6 days la 10m views dhana Waste .......vaipu ella rajq
# Predicted Label: Non-sarcastic
#
# Text: Vera level str,vj sp,as,av,&mr,well arr bgm sir
# Predicted Label: Sarcastic
#
# ...
# Predicted Label: Non-sarcastic
#
# Text: Hip Hop Tamizha Fans Like Pooduga.....
# Predicted Label: Sarcastic
#
# Text: மிஷ்கின் சார் நீங்க வேறலெவல் கிரயேட்டர்...
# Predicted Label: Non-sarcastic
#
# Text: Fdfs paathathan pongal diwaliya irukka mudiyum
# Predicted Label: Sarcastic
#
# Text: அகமுடையார் சார்பாக படம் வெற்றியடைய வாழ்த்துக்கள்
# Predicted Label: Non-sarcastic
#
# Text: Vellakkaranai tamilnattukulla vitta, sowrashtrakaranaiyum tamilnatukulla vitta, avangalukkellam ethanai pengalai koottikoduthiruppinga ana ippo anda paramparai, penda paramparai nu solringa vekkam illa?
# Predicted Label: Non-sarcastic
#
# Text: I wonder Why dis video s not trending ???
# Predicted Label: Sarcastic
#
# Text: Suriya annan & lalettan teaser polichu
# Predicted Label: Non-sarcastic
#
# Text: ЧИТАТЬ НОВОСТЬ ПАРТНЕРСКАЯ ПРОГРАММА ФИНАНСЫ ЧАВО О КОМПАНИИ      ЧИТАТЬ НОВОСТЬ  ВЫ ЧИТАЙТЕ НОВОСТИ
# Predicted Label: Non-sarcastic
#
# Text: vera level panraru VJS. Neenga vaena oorukula pousa thiriyalam... aaanaaa en maaasssss theriyaaathulaaaaa
# Predicted Label: Non-sarcastic
#
# Text: Ommala verha level last dialogue
# Predicted Label: Non-sarcastic
#
# Text: Semmaya.. ethu 96 🤣🤣🤣🤣 vera level
# Predicted Label: Sarcastic
#
# Text: Yarellam comments mattum pakka vanthinga
# Predicted Label: Non-sarcastic
#
# Text: Thevidiya Ajith fans kadharal autolike da nu
# Predicted Label: Sarcastic
#
# Text: Aiyooo !!!! Trailerey Cinema maadhiri irrukkey !!! Thalaivara ethanai dhadavayavathu paarkalaam !!!!
# Predicted Label: Sarcastic
#
# Text: Koi hindi comment karne wala hai kya.
# Predicted Label: Non-sarcastic
#
# Text: The word vera level thalaiva unaku vayase agadha paaaa
# Predicted Label: Non-sarcastic
#
# Text: En innum trending la varala? Ennada panringa YouTube fellows?
# Predicted Label: Non-sarcastic
#
# Text: Jathi Veri piditha mirugangalal Matumae ipdi Oru padathai kuduka mudiyum, paratavum mudiyum.. Grow up guys...
# Predicted Label: Non-sarcastic
#
# Text: Enna da elarum Vanda. Vandaya kilicha aprom trend aagudhu sun pictures kekadha kadhuku headset ah
# Predicted Label: Non-sarcastic
#
# Text: Trailer paaka munnadiye like poatachu :)
# Predicted Label: Non-sarcastic
#
# Text: Nan Vijay fan irunthalum Ajith ah pidikkum super
# Predicted Label: Non-sarcastic
#
# Text: Comment paka vatha legends like here
# Predicted Label: Non-sarcastic
#
# Text: Kabhi kabhi to lagta hai south waalon ki language sikhlun.
# Predicted Label: Non-sarcastic
#
# Text: Unlike pannava ava amma ellam item tha Thevadiyanga pasangala Ungamma koothingala kilichiduvan
# Predicted Label: Sarcastic
#
# Text: Venniradai moorthy ya yaaru nadikura padathula??
# Predicted Label: Non-sarcastic
#
# Text: Eppa ranjithu paru epdi irukku trailor
# Predicted Label: Non-sarcastic
#
# Text: Avlo onnum nalla illa sumar than padam odrathu konjam kastam
# Predicted Label: Sarcastic
#
# Text: சமுதாயத்திற்கு மிக முக்கியமான மிக முக்கியமான ஒன்று மாபெரும் வெற்றி பெற வாழ்த்துக்கள் இப்படிக்கு மாவீரன் தம்பிகள்
# Predicted Label: Non-sarcastic
#
# Text: 6.5 k dislikers is marvel and Cameroon fans
# Predicted Label: Sarcastic
#
# Text: Iva ketta Ketukku Movie Verayaa appdiye andha 60 Crores DA Case um kaata vendiyathu da padathula
# Predicted Label: Non-sarcastic
#
# Text: ATLEE ATLEE nu katharitu iruka AJITH fans....Still Siruthai  Siva  finds Vanathai pola ,Aiii,Muratu kalai,Thirupachi,sivakasi,Suryavamsam  pazhaya MGR Padam kind of stuff to make Veeram,vedalam,visuwasam ..... Siruthai vitutan la Athu Already Rajamouli Vikramarkudu.... Evanum ozhungu illa ATLEE kita matum vandhuduvanunga
# Predicted Label: Non-sarcastic
#
# Text: கள்ளக்குறிச்சி வன்னியர் சங்கம் சார்பாக படம் வெற்றிபெற வாழ்த்துக்கள்
# Predicted Label: Sarcastic
#
# Text: மெர்சல் விஜய்ய என்னடா பன்னி வெச்சிருக்கீங்க 🤣🤣🤣🤣🤣
# Predicted Label: Non-sarcastic
#
# Text: திருச்சி 🦁சூரிய குல சத்திரிய முத்தரையர்கள்🦁  சார்பில் வெற்றி அடைய வாழ்த்துக்கள்
# Predicted Label: Non-sarcastic
#
# Text: inum 2 days kulla 1million like varananum pangukala
# Predicted Label: Non-sarcastic
#
# Text: dai punda pudikalana odi poiru una yaru nakka sona
# Predicted Label: Non-sarcastic
#
# Text: Tamil nadimarke oru puthiya velluvilliakkumooo manju chechiudea puthiya entry
# Predicted Label: Non-sarcastic
#
# Text: Anna vere level .maranaa masss  .kollamasss
# Predicted Label: Sarcastic
#
# Text: Six district maravargall saarbaga vazlthukalll
# Predicted Label: Non-sarcastic
#
# Text: மிகப்பெரிய வெற்றி பெறவாழ்த்துக்கள்director  Mohan G
# Predicted Label: Non-sarcastic
#
# Text: Trailer maranna mass  thalaivar therika vidrarruuuu
# Predicted Label: Sarcastic
#
# Text: எந்த மேடையில் திருமாவளவன் பெரிய விட்டு பெண்ண திருமணம் பன்ன சொன்னாரு video link kudunga nanba
# Predicted Label: Non-sarcastic
#
# Text: Shankar giving suggession to Upendra  Lol
# Predicted Label: Sarcastic
#
# Text: Mohanlaline kanan teaser kandavR like adi
# Predicted Label: Non-sarcastic
#
# Text: Nee Enna Periya Vasul Mannana Theriyala Appadithan Pesikiranga Thalapathi Mass Da
# Predicted Label: Sarcastic
#
# Text: Soori irukar padam confirm flop dhan
# Predicted Label: Non-sarcastic
#
# Text: Hey idhu 96   yaraa emathuringa   sema bangam
# Predicted Label: Non-sarcastic
#
# Text: Marutthuva samudhayathinar saarbaaga vetri pera vaazhthukkal
# Predicted Label: Sarcastic
#
# Text: iooooooo enna solrathu be theriyala thalaivaaaa
# Predicted Label: Non-sarcastic
#
# Text: ending la  rajini dance patha sirippu tha varuthu
# Predicted Label: Non-sarcastic
#
# Text: Positive point-rajini sir Negative point-rajini sir...... kaala is perfect movie superstar.....
# Predicted Label: Sarcastic
#
# Text: Trailer semmaaayaaaa ithukkuuuuu come back jivaaa sir
# Predicted Label: Non-sarcastic
#
# Text: விருமாண்டி படத்தில் வருவதை போல, ஒரே கருத்தை இருவேறு கோணங்களில் கூறுகிறார்கள்... உண்மையில் இவற்றால் அரசியல்வாதிகள் மட்டுமே பயனடைவார்கள்... அடித்தட்டு மக்களை சாதியால் பிரித்து தனது பிம்பத்தை உயர்த்திக் கொள்வார்கள்
# Predicted Label: Non-sarcastic
#
# Text: தமிழ் மொழியை படைத்தவன் , வளர்த்தவன் இந்த பறையன் ,இந்த பெருமை போதும்
# Predicted Label: Sarcastic
#
# Text: தல அஜித் அவர்களின் 25 வருட திரைப்பயணத்தின் கடின உழைப்பை முற்றிலும் பிரதிபலிக்கிறது இந்த இரண்டரை நிமிட முன்னோட்டம். விவேகம் குழுவிற்கு எமது வாழ்த்துக்கள்.
# Predicted Label: Sarcastic
#
# Text: Oscar award ku mela award erutha thagada enga thalaivan actioning evalo mass eruku
# Predicted Label: Non-sarcastic
#
# Text: Semma trailer..... appo film yeppadi erukkum.... super
# Predicted Label: Non-sarcastic
#
# Text: naan video paakamaye like potutenlike pota 1 hr kalichu ipo dhan trailer full ah paakurenThala masss
# Predicted Label: Non-sarcastic
#
# Text: Haters - stop making violent films ! Vetrimaran - HOLD MY ASURAN !
# Predicted Label: Non-sarcastic
#
# Text: thalaiva unna paathona uyir poiyudichu...yenna Mazz,yenna class,yenna style...RAJINISM CONFIRMED
# Predicted Label: Non-sarcastic
#
# Text: Oruthar mela nenga #Viswasam Katurathuku innoruthara Ae Asinga PADUTHURIGA....   Thala nega vera level 🤙🤙🤙
# Predicted Label: Non-sarcastic
#
# Text: 353 rd like suriya anna veriyan daaaa
# Predicted Label: Non-sarcastic
#
# Text: செம்மையான  ட்ரைலர் யா வாழ்த்துக்கள்( பாத்துட்டு சாவுங்கடா )
# Predicted Label: Sarcastic
#
# Text: Coments paathale sirippu varuthu'nu solluravanga mattum like ...
# Predicted Label: Non-sarcastic
#
# Text: அடக்க மறு அத்து மிரு செருப்பு எடு வாயில அடி குருமா குஞ்சுக்கோ
# Predicted Label: Sarcastic
#
# Text: yarra yarra ivan ooraketta theriyum parra munna vanthu ninnu parra puriyum varlam varlam varlamva bairavaa mass theme music vj anna
# Predicted Label: Sarcastic
#
# Text: “Indha kayiru irukura varaikkum onnum aavadhu....”   Saami kayanduchinaaa???
# Predicted Label: Sarcastic
#
# Text: என்ன சொல்றதுண்ணே தெர்ல சார்...   காபி சொல்லுங்க..
# Predicted Label: Non-sarcastic
#
# Text: #thala Pola varuma therika vitutapula manishan
# Predicted Label: Non-sarcastic
#
# Text: Tribute to 2.0 Support us #2.0 #shankar sir #Rajani sir
# Predicted Label: Sarcastic
#
# Text: Visvasam padam eranguna piragu idha pargiravanga like podunga
# Predicted Label: Non-sarcastic
#
# Text: ஊராளிகவுண்டர்கள் சார்பாக மனமார்ந்த நன்றி இயக்குனரே.எங்களுடைய மனக்குமுறலை  திரைப்படத்தில் கொண்டு வந்ததற்கு நன்றி.
# Predicted Label: Non-sarcastic
#
# Text: Pakka mass!!!!!  But Editing la oru small mistake thalaivar Rajini spelling ah thappa potutingale paaa introduction la
# Predicted Label: Non-sarcastic
#
# Text: இந்தபடம் மிகப் பெரிய வெற்றியடைய எனது வாழ்த்துக்கள்.
# Predicted Label: Non-sarcastic
#
# Text: Nichayamaa intha thiraipadam summa ninnu pesum
# Predicted Label: Non-sarcastic
#
# Text: மற்ற சமூகத்தில் யாரும் எந்த பெண்களையும் ஏமாற்ற வில்லையா குறிப்பிட்ட சமூகத்தை மட்டும் குறிப்பிட்டு எடுப்பதற்கான காரணம் என்ன தவறு அனைத்து சமூக இளைஞர்களும் செய்கின்றனர் ஏதோ இவர்கள் எல்லாம் ஒன்றும் தெரியாத குழைந்தகள் போலவும் குறிப்பிட்ட சமூகம் மட்டும்தான் தவறு செய்வது போலவும் ஒரு பிம்பத்தை ஏற்படுத்துகின்றனர் உண்மையாக காதலித்து திருமணம் செய்து கொண்டாலும் ஆணவகொலை செய்து வாழ விடாமல்  உங்கள் ஜாதி வெறியை தீர்த்து கொள்கின்றனர் நீங்கள் சொல்லும் குறிப்பிட்ட சமூகத்தில் உண்மையாக காதலித்து திருமணம் செய்து கொண்டு வாழத்தான் செய்கின்றனர் மற்ற சமூகத்தில் நாடக காதல் செய்யவில்லையா இங்கு காதலிப்பது பிரச்சனையா இல்லை அவர்கள் உங்கள் பெண்களை காதலிப்பது பிரச்சனையா
# Predicted Label: Non-sarcastic
#
# Text: உடையார் குலம் சார்பாக படம் வெற்றி பெற வாழ்த்துக்கள்
# Predicted Label: Non-sarcastic
#
# Text: Pongalukku  Sirappana, Tharamana, Mass entertainer flim
# Predicted Label: Sarcastic
#
# Text: அனைத்து நாயக்கர் அமைப்புகளின் சார்பாக வாழ்த்துக்கள்.. இவன்: வீரபாண்டிய கட்டபொம்மன் நாயக்கர் மற்றும் திருமலை நாயக்கர் பேரவை
# Predicted Label: Non-sarcastic
#
# Text: Enna Solradunu Terila Coffee Sollu  Dialogue Writer - Palaya Joke Thangadurai
# Predicted Label: Sarcastic
#
# Text: Andha loosu atlee movie ku kaidhi evlo nalla iruku Andha vijay ku acting ae varadhu
# Predicted Label: Sarcastic
#
# Text: Yuvan  bgm vere level.     Katta support  from ikkaaa fan
# Predicted Label: Non-sarcastic
#
# Text: தமிழ்நாடு யாதவர் சமுதாயம் சார்பில் படம் வெற்றி பெற வாழ்த்துக்கள்  அன்றாட வாழ்வில் நடக்கும் சம்பவங்களை அருமையான கதை வடிவில் கொடுத்தமைக்கு நன்றி
# Predicted Label: Non-sarcastic
#
# Text: Adai thalaivara ena Da panni vachurukinga
# Predicted Label: Non-sarcastic
#
# Text: Trailer nalla irukku 90skids niyabagam paduthum
# Predicted Label: Non-sarcastic
#
# Text: pathute  iruken thalaiva summa alluthu
# Predicted Label: Non-sarcastic
#
# Text: Na arasiyaluku varuvathu uruthi...  Yeeeee ithu 1996...
# Predicted Label: Sarcastic
#
# Text: WW3'ye vara pooguthu... ivanuga innum velu kammba ah eduthuthu saadhikaaga adichukkaraanuga
# Predicted Label: Non-sarcastic
#
# Text: Ennum oru rendu movie release aagatum... Aprm irukuthu
# Predicted Label: Non-sarcastic
#
# Text: Dai manasaatchi illama dislike pandringale da.....Proud Tamil movie da vennaigala
# Predicted Label: Non-sarcastic
#
# Text: Ippadi oru padam vanthavathu indraya thalaimurai en kula pengalukku nallathu ethu kettathu ethunu theriyattum
# Predicted Label: Non-sarcastic
#
# Text: Theme song same like thala nerkonda paarvai 🤔
# Predicted Label: Sarcastic
#
# Text: OMG... Pakkka mass... Vera level... Thalaivaaa... I love u...
# Predicted Label: Sarcastic
#
# Text: Vetta. Ready  nanga enga ayyya Ramadass  kannu asacha. Tamilnatta azhichuduvom Veera vanniyan
# Predicted Label: Non-sarcastic
#
# Text: Super star Rajinikanth fans ikkada oka like vesukondi all movies break in 2.O movie pakka
# Predicted Label: Non-sarcastic
#
# Text: Super perfect excellent Mass illla marana massssssssa
# Predicted Label: Non-sarcastic
#
# Text: Marana waiting movie ku trailer mass aa iruku
# Predicted Label: Sarcastic
#
# Text: Thalaiva superstar Rajinikanth very very super
# Predicted Label: Non-sarcastic
#
# Text: ஒரு டிரெய்லர் ரிலீஸ் ......        அனைத்து சமுதாயத்தையும் ஒன்று சேர   வைத்ததில் பெருமகிழ்ச்சி......
# Predicted Label: Sarcastic
#
# Text: Cellphone ceiling a odachutu poguda?  Ena Dan padama irundalum oru nyayam vendama da
# Predicted Label: Sarcastic
#
# Text: singam horse la vettai yaada varudhu...
# Predicted Label: Non-sarcastic
#
# Text: sila peru avanga polappukaga thalathalapathy fandom vachi drama pandranga...
# Predicted Label: Non-sarcastic
#
# Text: Yenga ooru getthu waiting for movie
# Predicted Label: Non-sarcastic
#
# Text: Movie kab ayga hindi dubbit me
# Predicted Label: Non-sarcastic
#
# Text: Zero is quite better than 2.0
# Predicted Label: Non-sarcastic
#
# Text: நான் இவனுக்கு கீழே நான் இவனுக்கு கீழே என்று சொல்லுறதுல இவ்ளோ ஆனந்தம் இருக்க எல்லாருக்கும் What the hell is that
# Predicted Label: Non-sarcastic
#
# Text: Inum thirundhadha oru samugam ah dhan iruku.. Sadhi ah pathi pesama irundhale makkal ondru patu irupanga..  Paditha makkal vandha dhan samugam ondru padum..
# Predicted Label: Non-sarcastic
#
# Text: 90s kits Ku oru sema treat
# Predicted Label: Non-sarcastic
#
# Text: Bro idhu kakkabekka short film madhiri irukki
# Predicted Label: Non-sarcastic
#
# Text: rch ayachu da thalapathy rocks enga pa antha s3 address ey kaanom
# Predicted Label: Non-sarcastic
#
# Text: Director damilan daa group poola....Thalaivar 96 la eppo da arasiyaluku varaen nu sonnaru. Sonnathu 2016 la..
# Predicted Label: Non-sarcastic
#
# Text: Who is best trailer...?  Nerkonda paarvai   Sindhubaadh
# Predicted Label: Sarcastic
#
# Text: எங்க அப்ப மில்டிரிடா கோலி விளாடவா சொல்லிதருவா
# Predicted Label: Non-sarcastic
#
# Text: கமெண்ட் செய்த அனைத்து உள்ளங்களுக்கும் நன்றி ஆனால்   தர்பார் படத்தை இன்னும் நிறைய தியேட்டரில் திரையிட இருக்கும் போது நாம் அனைவரும் பார்ப்பது நடக்குமா ?
# Predicted Label: Sarcastic
#
# Text: Thirboki nanmakla kannada trailer nalli comment madro ,parabashigaru avra abipraya thilsli,ellodru vakraskondu saythira,
# Predicted Label: Non-sarcastic
#
# Text: Dei over built up ah irukkey..thambi  Intha padamachu oduma?
# Predicted Label: Sarcastic
#
# Text: But still vadivelu is the best hostel warden ever :)
# Predicted Label: Non-sarcastic
#
# Text: வேலூர் மாவட்டம் சார்பாக படம் மாபெரும் வெற்றி பெற மனதார வாழ்த்துக்கள்
# Predicted Label: Non-sarcastic
#
# Text: Antha last scene redmi note 5 pro le shoot panna maari irukku
# Predicted Label: Non-sarcastic
#
# Text: Angali pangali anaivarukkum Kalai Vanakam
# Predicted Label: Non-sarcastic
#
# Text: Indha padattha patthukkuttu irukkum podhu un ootu ponna thookkikittu poira porano  patthu siringada...
# Predicted Label: Non-sarcastic
#
# Text: இயக்குனரை வன்மையாக கண்டிக்கிறேன். நாடக காதல் என்கிறீர்கள், அதற்கான ஆதாரத்தை உங்களால் காட்ட முடியுமா. உண்மை தெரியாமல் படமெடுத்துள்ளான் முட்டாள் இயக்குனர்.. காதலில் சாதியை புகுத்தி மனிதர்களை பிரிக்காதீரீகள்.
# Predicted Label: Non-sarcastic
#
# Text: Romba days apparam thamil cinema lla  nalla movie,varapothu
# Predicted Label: Non-sarcastic
#
# Text: That vijay smile... Rajini sir kudos
# Predicted Label: Non-sarcastic
#
# Text: Today my birthday friends koi wish karega yr
# Predicted Label: Non-sarcastic
#
# Text: Selva & Yuvan fans hit like
# Predicted Label: Non-sarcastic
#
# Text: மக்களே please எல்லாரும் போய் படத்த பார்க்கணும் இதை ஒரு வெற்றி படமா நாம ஆக்கணும்.
# Predicted Label: Sarcastic
#
# Text: தோழர் அனைவருக்கும் என்னுடைய வாழ்த்துக்கள் இந்த படத்திற்கு இது நீங்கள் சாதி வெறியை கூட்டுகிறது திரை என்பது ஒரு பொழுதுபோக்கு மட்டுமே அதை தவிர்த்து எமது இளைஞர்களை தவறான பாதையில் இட்டுச் செல்ல வேண்டாம் ஏழாவது படி விழுத்திய வருகிறது எனவே எமது இளைஞர்கள் விழிப்புடன் இருக்க வேண்டும் சாதியும் இல்லை மதமும் இல்லை ஓர் இனம் மனித இனம் என்ற ஒரு அடிப்படைத் தத்துவத்திற்கு வாருங்கள் அனைவரும் ஒன்று சேர்ந்து வறுமை ஒழிப்பு இங்கே சிலபேர் வாழ்வதற்கு பல பேரை சாதிவெறியை தூண்டப்படுகிறது எனவே நாம் அனைவரும் ஒன்று சேர்ந்து வறுமையை ஒழிப்போம் நேர்மையாளர் ஒன்றிணைவோம் வாரீர்
# Predicted Label: Non-sarcastic
#
# Text: மஹா பிரபு Bethovan லயே கைய வச்சிட்டிங்களா? இந்த விஷயம் அனிருத் தம்பிக்கு தெரியாம பாத்துக்குங்க.... பயபுள்ள சும்மா O2 ஓளர விடுவாப்டி, #bethorajashkin
# Predicted Label: Non-sarcastic
#
# Text: Seriyana serupadi. Kutham panavam ninchu kuru kurunu irukum. Ponnuga life ha yamathi pala kudumbatha azijudu poravanku serupadi
# Predicted Label: Non-sarcastic
#
# Text: Yamma Rj anandhi ithu padam ma fm illa serious ana dialogue ah ipdi fm radio mathiri akitiye ma!!
# Predicted Label: Sarcastic
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-8dbf8027c3c8> in <cell line: 2>()
#       1 # Print the predictions
#       2 for i, text in enumerate(test_texts):
# ----> 3     print(f"Text: {text}\nPredicted Label: {predicted_labels[i]}\n")
#
# IndexError: index 5914 is out of bounds for axis 0 with size 5914
